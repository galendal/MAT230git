# %%
import scipy
import phase_portr as pp
import math

import ipywidgets as wd
import numpy as np
import matplotlib.pyplot as plt
import sympy as symp
# %matplotlib inline

import ipywidgets as wd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Define 
x,y, t=symp.symbols('x y t')


f=y*(1-x**2)
g=-x*(1-y**2)
J = symp.Function('J')(x,y)

# %% [markdown]
# ## Exercise 2
# ### a)
#
# $$\dot{x}=0 $$
# $$\dot{y}=x+2 y $$

# %%
f=0
g=x+2*y

def rhs(xy,t):
    xv,yv=xy
    rhs_symp=symp.lambdify((x,y),[f,g])
    return np.array(rhs_symp(xv,yv))

print('f=',f)
print('g=',g)
### Isoclines

xiso=symp.solve(f,y)
yiso=symp.solve(g,y)
print('f = 0 when', xiso)
print('g = 0 when y=', yiso)

### Equilibrium points
eqpnts=symp.solve([f,g],(x,y))
print('Equilibrium points. ', eqpnts)

### Jacobian
J=symp.Matrix([f,g]).jacobian([x,y])
print('Jacobian J=',J)

print('Eigenvalues:', J.subs(eqpnts).eigenvals())

print()

print('Eigenvectors: ')
symp.pprint(J.subs(eqpnts).eigenvects())
# Set up the figure
fig, ax = plt.subplots(1, 1)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_aspect('equal')

# Build the plot
a_range = [-2, 2]
b_range = [-2, 2]
ax = pp.plot_flow_field(ax, rhs, a_range, b_range)
ax = pp.plot_fixed_points(ax, np.array([0,0]),color='red')
ax = pp.plot_nullcl(ax, rhs, [-2, 2], [-2, 2], args=(), n_grid=100)
ax = pp.plot_traj(ax, rhs, np.array([-1, -1]), np.linspace(0, 10, 50), color=np.array([0.5, 0.5, 0.5]), lw=2)
ax = pp.plot_traj(ax, rhs, np.array([0, 2]), np.linspace(0, 10, 50), color=np.array([0.5, 0.5, 0.5]), lw=2)

ax = pp.plot_traj(ax, rhs, np.array([-2, 2]), np.linspace(0, 10, 50), color='black', lw=2)
ax = pp.plot_traj(ax, rhs, np.array([2, -2]), np.linspace(0, 10, 50), color='black', lw=2)

ax = pp.plot_traj(ax, rhs, np.array([-1, 2]), np.linspace(0, 10, 50), color='green', lw=2)
ax = pp.plot_traj(ax, rhs, np.array([1, -2]), np.linspace(0, 10, 50), color='green', lw=2)
plt.xlim(a_range)
plt.ylim(b_range)
# Out:
# f= 0
# g= x + 2*y
# f = 0 when []
# g = 0 when y= [-x/2]
# Equilibrium points.  {x: -2*y}
# Jacobian J= Matrix([[0, 0], [1, 2]])
# Eigenvalues: {0: 1, 2: 1}
#
# Eigenvectors:
# ⎡⎛      ⎡⎡-2⎤⎤⎞  ⎛      ⎡⎡0⎤⎤⎞⎤
# ⎢⎜0, 1, ⎢⎢  ⎥⎥⎟, ⎜2, 1, ⎢⎢ ⎥⎥⎟⎥
# ⎣⎝      ⎣⎣1 ⎦⎦⎠  ⎝      ⎣⎣1⎦⎦⎠⎦
# /Users/guttorm/Dropbox/Kurs/MAT230/Github/MAT230git/phase_portr.py:112: UserWarning: No contour levels were found within the data range.
#   cs1=ax.contour(uu, vv, u_vel, [0],
# (-2.0, 2.0)

# %% [markdown]
# ### 2d)
# $$\dot{x}=3 x + y $$
# $$\dot{y}= - x + 3 y $$
#
# Eigenvectors:
# $$ \lambda_1= -2, \ \ \underline{v}_1 = \left[ \begin{array}{c} 1\\ 2 \end{array} \right] $$
#
#
# $$ \lambda_2= 0, \ \ \underline{v}_2 = \left[ \begin{array}{c} 3 \\ 4 \end{array} \right] $$

# %%
def rhs(xy,t):
    xv,yv=xy
    rhs_symp=symp.lambdify((x,y),[f,g])
    return np.array(rhs_symp(xv,yv))

fig, ax = plt.subplots(1, 1)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_aspect('equal')

# Build the plot
a_range = [-4, 4]
b_range = [-4, 4]
ax = pp.plot_flow_field(ax, rhs, a_range, b_range)

ax = pp.plot_nullcl(ax, rhs, [-2, 2], [-2, 2], args=(), n_grid=100)

# %% [markdown]
# ## 2e)

# %%
f=y
g=-x-2*y

symp.pprint(symp.Matrix([f,g]).jacobian([x,y]).eigenvects())
# Out:
# ⎡⎛       ⎡⎡-1⎤⎤⎞⎤
# ⎢⎜-1, 2, ⎢⎢  ⎥⎥⎟⎥
# ⎣⎝       ⎣⎣1 ⎦⎦⎠⎦

# %%
def rhs_2e(xy, t):
    x, y = xy
    return np.array([y,
                     -x-2*y])
# Set up the figure
fig, ax = plt.subplots(1, 1)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_aspect('equal')

# Build the plot
a_range = [-2, 2]
b_range = [-2, 2]
ax = pp.plot_flow_field(ax, rhs_2e, a_range, b_range)

ax = pp.plot_nullcl(ax, rhs_2e, [-2, 2], [-2, 2], args=(), n_grid=100)

# %% [markdown]
# ## 2f)

# %%
f=x-y
g=y-x

symp.pprint(symp.Matrix([f,g]).jacobian([x,y]).eigenvects())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-5abe69d58daf> in <module>
# ----> 1 f=x-y
#       2 g=y-x
#       3
#       4 symp.pprint(symp.Matrix([f,g]).jacobian([x,y]).eigenvects())
#
# NameError: name 'x' is not defined

# %%
symp.solve({f,g})
# Out:
# {x: y}

# %% [markdown]
# ## 4a)

# %%
f=y
g=x-y+x**3
symp.solve({f,g})
# Out:
# [{x: 0, y: 0}]

# %%
J=(symp.Matrix([f,g]).jacobian([x,y]))

# %%
J.subs({x:0}).eigenvects()
# Out:
# [(-1/2 + sqrt(5)/2,
#   1,
#   [Matrix([
#    [1/2 + sqrt(5)/2],
#    [              1]])]),
#  (-sqrt(5)/2 - 1/2,
#   1,
#   [Matrix([
#    [1/2 - sqrt(5)/2],
#    [              1]])])]

# %%
def rhs_4a(xy, t):
    x, y = xy
    return np.array([y,
                     x-y+x**3])
# Set up the figure
fig, ax = plt.subplots(1, 1)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_aspect('equal')

# Build the plot
a_range = [-2, 2]
b_range = [-2, 2]
ax = pp.plot_flow_field(ax, rhs_4a, a_range, b_range)

ax = pp.plot_nullcl(ax, rhs_4a, [-2, 2], [-2, 2], args=(), n_grid=100)

# %% [markdown]
# ## 4 b)

# %%
f=-2*x-y+2 
g=x*y
symp.solve({f,g})
# Out:
# [{x: 0, y: 2}, {x: 1, y: 0}]

# %%
J=(symp.Matrix([f,g]).jacobian([x,y]))

# %%
J
# Out:
# Matrix([
# [-2, -1],
# [ y,  x]])

# %%
J.subs({x:0,y:2}).eigenvals()
# Out:
# {-1 - I: 1, -1 + I: 1}

# %%
def rhs_4b(xy, t):
    x, y = xy
    return np.array([-2*x-y+2 ,
                     x*y])
# Set up the figure
fig, ax = plt.subplots(1, 1)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_aspect('equal')

# Build the plot
a_range = [-4, 4]
b_range = [-4, 4]
ax = pp.plot_flow_field(ax, rhs_4b, a_range, b_range)

ax = pp.plot_nullcl(ax, rhs_4b, [-4, 4], [-4, 4], args=(), n_grid=100)

# %% [markdown]
# ## 4c)

# %%
f=x**2-y**2
g=x*y-1
eqpts=symp.solve({f,g})
eqpts
# Out:
# [{x: -1, y: -1}, {x: 1, y: 1}]

# %%
J=(symp.Matrix([f,g]).jacobian([x,y]))
J
# Out:
# Matrix([
# [2*x, -2*y],
# [  y,    x]])

# %%
J.subs(eqpts[0]).eigenvals()
# Out:
# {-3/2 - sqrt(7)*I/2: 1, -3/2 + sqrt(7)*I/2: 1}

# %%
def rhs_4c(xy, t):
    x, y = xy
    return np.array([x**2-y**2,
                     x*y-1])
# Set up the figure
fig, ax = plt.subplots(1, 1)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_aspect('equal')

# Build the plot
a_range = [-6, 6]
b_range = [-6, 6]
ax = pp.plot_flow_field(ax, rhs_4c, a_range, b_range)

ax = pp.plot_nullcl(ax, rhs_4c, [-4, 4], [-4, 4], args=(), n_grid=100)

# %% [markdown]
# ## 4d)

# %%
f=2-x-y**2
g=-y*(x**2+y**2-3*x+1)
eqpts=symp.solve({f,g})
eqpts
# Out:
# [{x: 1, y: -1}, {x: 1, y: 1}, {x: 2, y: 0}]

# %%
J=(symp.Matrix([f,g]).jacobian([x,y]))
J
# Out:
# Matrix([
# [          -1,                     -2*y],
# [-y*(2*x - 3), -x**2 + 3*x - 3*y**2 - 1]])

# %%
J.subs(eqpts[2]).eigenvals()
# Out:
# {-1: 1, 1: 1}

# %%
def rhs_4d(xy, t):
    x, y = xy
    return np.array([2-x-y**2,
                     -y*(x**2+y**2-3*x+1)])
# Set up the figure
fig, ax = plt.subplots(1, 1)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_aspect('equal')

# Build the plot
a_range = [-2, 4]
b_range = [-2, 4]
ax = pp.plot_flow_field(ax, rhs_4d, a_range, b_range)

ax = pp.plot_nullcl(ax, rhs_4d, [-2, 4], [-2, 4], args=(), n_grid=100)

# %%
g=-y*(x**2+y**2-3*x+1)
